# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/customer_churn.csv')

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.duplicated().sum().sum()
# Out:
# 0

# %%
data["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.pie(data["Churn"].value_counts(), autopct= "%0.2f%%", labels = ["DID NOT churned", "churn"])
plt.show()

# %%
for i in data.columns:
    if data[i].dtype != object:
        plt.figure(figsize=(5,5))
        sns.displot(data[i])

# %%
x= data['InternetService'].value_counts().keys()
y= data['InternetService'].value_counts()
plt.bar(x,y,color='purple')
plt.xlabel('Categories of Internet Service')
plt.ylabel('Count of Categories')
plt.title('InternetService')
# Out:
# Text(0.5, 1.0, 'InternetService')

# %%
payment_method_counts = data['PaymentMethod'].value_counts()
plt.pie(payment_method_counts, labels=payment_method_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Payment Method')
plt.show()

# %%
plt.pie(data["InternetService"].value_counts(), autopct= "%0.2f%%", labels = ["DSL", "Fiber" , " Optic"])
plt.show()

# %%
plt.figure(figsize =  (10 , 5))
sns.countplot(data = data , x = 'gender' , hue = 'PaymentMethod')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
# how many has multiple lines and no service

x= data['MultipleLines'].value_counts().keys()
y= data['MultipleLines'].value_counts()
plt.bar(x,y,color='green')
plt.xlabel('Categories of MultipleLines')
plt.ylabel('Count of Categories')
plt.title('MultipleLines')
# Out:
# Text(0.5, 1.0, 'MultipleLines')

# %%
sns.pairplot(hue = "Churn", data = data)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(numeric_only = True), annot = True)
# Out:
# <Axes: >

# %%
# Label Encoding

from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

for column in data.columns:
    if data[column].dtype == object:
        data[column] = label_encoder.fit_transform(data[column])

# %%
x = data.drop(["customerID", "Churn"], axis = 1)
y = data["Churn"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 100) #  number of decision trees = 100
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7806955287437899

# %%
n = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

for i in n:
    model = RandomForestClassifier(n_estimators = i)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy for {i} estimators is {accuracy}")
# Out:
# Accuracy for 100 estimators is 0.7849538679914834
# Accuracy for 200 estimators is 0.7799858055358411
# Accuracy for 300 estimators is 0.7806955287437899
# Accuracy for 400 estimators is 0.7806955287437899
# Accuracy for 500 estimators is 0.78708303761533
# Accuracy for 600 estimators is 0.7814052519517388
# Accuracy for 700 estimators is 0.7821149751596878
# Accuracy for 800 estimators is 0.7863733144073811
# Accuracy for 900 estimators is 0.7828246983676366
# Accuracy for 1000 estimators is 0.7828246983676366

# %%
# Grid Search Cv

from sklearn.model_selection import GridSearchCV

parameters = {
    "n_estimators" : [100, 200, 300],
    "criterion" : ["gini", "entropy"],
    "max_depth" : [1, 2, 3]
}

grid_search = GridSearchCV(estimator = model, param_grid = parameters)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(n_estimators=1000),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3],
#                          'n_estimators': [100, 200, 300]})

# %%
print(grid_search.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'n_estimators': 200}

# %%
model2 = RandomForestClassifier(criterion = 'gini', max_depth = 3, n_estimators = 100)
model2.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3)

# %%
predictions = model2.predict(x_test)

accuracy = accuracy_score(y_test, predictions)
accuracy
# Out:
# 0.7771469127040455

# %%
model2.feature_importances_
# Out:
# array([2.54643142e-04, 1.40024813e-03, 4.94140615e-03, 3.01049208e-03,
#        1.68425392e-01, 1.58306293e-04, 1.56747223e-03, 3.85988498e-02,
#        1.41088052e-01, 4.36993665e-02, 4.39207970e-02, 1.45889962e-01,
#        1.14881165e-03, 3.38075609e-03, 2.98921904e-01, 1.71009690e-02,
#        3.64846585e-02, 4.28123934e-02, 7.19551996e-03])

# %%
# Graphiz

from sklearn.tree import plot_tree

plt.figure(figsize = (15, 10))
plot_tree(model2.estimators_[99], filled = True)
# Out:
# [Text(0.5, 0.875, 'x[10] <= 0.5\ngini = 0.387\nsamples = 3549\nvalue = [4157, 1477]'),
#  Text(0.25, 0.625, 'x[16] <= 1.5\ngini = 0.473\nsamples = 1558\nvalue = [1530, 957]'),
#  Text(0.125, 0.375, 'x[14] <= 0.5\ngini = 0.389\nsamples = 531\nvalue = [631, 227]'),
#  Text(0.0625, 0.125, 'gini = 0.471\nsamples = 330\nvalue = [335, 205]'),
#  Text(0.1875, 0.125, 'gini = 0.129\nsamples = 201\nvalue = [296, 22]'),
#  Text(0.375, 0.375, 'x[7] <= 0.5\ngini = 0.495\nsamples = 1027\nvalue = [899, 730]'),
#  Text(0.3125, 0.125, 'gini = 0.406\nsamples = 419\nvalue = [478, 189]'),
#  Text(0.4375, 0.125, 'gini = 0.492\nsamples = 608\nvalue = [421, 541]'),
#  Text(0.75, 0.625, 'x[17] <= 83.675\ngini = 0.276\nsamples = 1991\nvalue = [2627, 520]'),
#  Text(0.625, 0.375, 'x[3] <= 0.5\ngini = 0.197\nsamples = 1288\nvalue = [1827, 228]'),
#  Text(0.5625, 0.125, 'gini = 0.239\nsamples = 799\nvalue = [1113, 179]'),
#  Text(0.6875, 0.125, 'gini = 0.12\nsamples = 489\nvalue = [714, 49]'),
# ...

# %%
from sklearn.tree import export_graphviz
import graphviz

tree = model2.estimators_[99]
dot_data = export_graphviz(tree)

graph = graphviz.Source(dot_data)
graph
